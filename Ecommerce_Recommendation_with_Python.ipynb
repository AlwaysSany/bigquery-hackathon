# %% [markdown]
# # Environment Setup & Configuration

# %%
import bigframes.pandas as bpd
import bigframes.bigquery as bbq
from bigframes.ml.llm import TextEmbeddingGenerator
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import warnings
warnings.filterwarnings('ignore')

# 🔧 Project Configuration - CHANGE THESE TO YOUR VALUES
PROJECT_ID = "bigquery-hackathon-471715"  # @param {type:"string"} # Your Google Cloud Project ID
DATASET_ID = "thelook_ecommerce"          # @param {type:"string"} # The BigQuery dataset containing the product data
LOCATION = "US"                           # @param {type:"string"} # The location of your BigQuery dataset (e.g., "US", "EU")

# Configure BigFrames to use the specified project and location
bpd.options.bigquery.project = PROJECT_ID
bpd.options.bigquery.location = LOCATION
bpd.options.display.max_columns = None # Allow displaying all columns in BigFrames DataFrames

print("Environment configured successfully!")
print(f"Project: {PROJECT_ID}")
print(f"Dataset: {DATASET_ID}")

# Quick data quality check
# This query checks the number of products, embeddings, and categories in the product_embeddings_clean table.
try:
    test_query = f"""
    SELECT COUNT(*) as product_count,
           COUNT(embedding) as embeddings_count,
           COUNT(DISTINCT category) as categories
    FROM `{PROJECT_ID}.{DATASET_ID}.product_embeddings_clean`
    """
    quality_check = bpd.read_gbq(test_query).to_pandas().iloc[0]
    print(f"Data Status: {quality_check['product_count']} products, {quality_check['embeddings_count']} embeddings, {quality_check['categories']} categories")
except Exception as e:
    # Handle potential errors (e.g., table not found, permissions issues)
    print(f"Warning: Could not connect to data. Error: {str(e)}")
# Out:
# Environment configured successfully!
# Project: bigquery-hackathon-471715
# Dataset: thelook_ecommerce
# Query job 36db07e9-9bdb-47bf-8a55-b5ac5db2e752 is DONE. 0 Bytes processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=bigquery-hackathon-471715&j=bq:US:36db07e9-9bdb-47bf-8a55-b5ac5db2e752&page=queryresults">Open Job</a>
# Query job 8991a0e7-93bb-46af-991c-25848a881d8f is DONE. 179.1 MB processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=bigquery-hackathon-471715&j=bq:US:8991a0e7-93bb-46af-991c-25848a881d8f&page=queryresults">Open Job</a>
# Data Status: 29094 products, 29094 embeddings, 26 categories

# %% [markdown]
# # Smart Product Explorer & Search

# %%
class SmartProductExplorer:
    """
    Enhanced product exploration with intelligent filtering.

    This class provides methods to load product data from BigQuery,
    perform smart searches across multiple product attributes, and
    generate comprehensive category insights.
    """

    def __init__(self, project_id, dataset_id):
        """
        Initializes the SmartProductExplorer.

        Args:
            project_id (str): The Google Cloud Project ID.
            dataset_id (str): The BigQuery dataset ID containing product data.
        """
        self.project_id = project_id
        self.dataset_id = dataset_id
        self.products_df = None

    def load_products_with_insights(self, limit=30000):
        """
        Load products from BigQuery with additional computed insights.

        Insights include embedding dimension, price tier, brand product count,
        category size, and brand tier based on product count.

        Args:
            limit (int): The maximum number of products to load.

        Returns:
            bigframes.dataframe.DataFrame: A DataFrame containing product data with insights.
        """
        query = f"""
        WITH product_insights AS (
            SELECT
                p.id, p.name, p.category, p.brand, p.retail_price,
                ARRAY_LENGTH(p.embedding) as embedding_dim,
                CASE
                    WHEN p.retail_price < 20 THEN 'Budget (Under $20)'
                    WHEN p.retail_price < 50 THEN 'Mid-Range ($20-$50)'
                    WHEN p.retail_price < 100 THEN 'Premium ($50-$100)'
                    ELSE 'Luxury ($100+)'
                END as price_tier,
                COUNT(*) OVER (PARTITION BY p.brand) as brand_product_count,
                COUNT(*) OVER (PARTITION BY p.category) as category_size
            FROM `{self.project_id}.{self.dataset_id}.product_embeddings_clean` p
        )
        SELECT *,
            CASE
                WHEN brand_product_count > 100 THEN 'Major Brand'
                WHEN brand_product_count > 20 THEN 'Popular Brand'
                ELSE 'Boutique Brand'
            END as brand_tier
        FROM product_insights
        ORDER BY retail_price DESC
        LIMIT {limit}
        """

        self.products_df = bpd.read_gbq(query)
        print(f"Loaded {len(self.products_df)} products with insights")
        return self.products_df

    def smart_search(self, search_term, max_results=10):
        """
        Perform an intelligent product search across name, category, and brand.

        Loads product data if not already loaded. Converts to pandas DataFrame
        for efficient string matching.

        Args:
            search_term (str): The term to search for.
            max_results (int): The maximum number of search results to return.

        Returns:
            pandas.DataFrame: A DataFrame containing the top matching products.
        """
        if self.products_df is None:
            self.load_products_with_insights()

        # Convert to pandas for complex filtering
        df = self.products_df.to_pandas()

        # Multi-criteria search
        search_lower = search_term.lower()
        matches = df[
            df['name'].str.lower().str.contains(search_lower, na=False) |
            df['category'].str.lower().str.contains(search_lower, na=False) |
            df['brand'].str.lower().str.contains(search_lower, na=False)
        ]

        print(f"Found {len(matches)} products matching '{search_term}'")
        return matches.head(max_results)

    def get_category_insights(self):
        """
        Get comprehensive statistics and insights for each product category.

        Includes product count, average, min, and max retail price, and
        the number of unique brands within each category.

        Returns:
            pandas.DataFrame: A DataFrame with category-level statistics,
                              sorted by product count in descending order.
        """
        df = self.products_df.to_pandas() if self.products_df is not None else None
        if df is None:
            self.load_products_with_insights()
            df = self.products_df.to_pandas()

        category_stats = df.groupby('category').agg({
            'id': 'count',
            'retail_price': ['mean', 'min', 'max'],
            'brand': 'nunique'
        }).round(2)

        category_stats.columns = ['product_count', 'avg_price', 'min_price', 'max_price', 'unique_brands']
        return category_stats.sort_values('product_count', ascending=False)

# %% [markdown]
# # Advanced Recommendation Engine

# %%
class AdvancedRecommendationEngine:
    """
    State-of-the-art recommendation engine with multiple algorithms.

    This class provides various recommendation algorithms, including pure semantic
    similarity, a hybrid approach combining semantic and product attributes, and
    a business-optimized approach considering profit margins. It also includes
    functionality to compare recommendations from different algorithms.
    """

    def __init__(self, project_id, dataset_id):
        """
        Initializes the AdvancedRecommendationEngine.

        Args:
            project_id (str): The Google Cloud Project ID.
            dataset_id (str): The BigQuery dataset ID containing product data.
        """
        self.project_id = project_id
        self.dataset_id = dataset_id
        self.recommendation_cache = {}

    def get_product_info(self, product_id):
        """
        Get detailed information for a specific product.

        Args:
            product_id (int): The ID of the product to retrieve information for.

        Returns:
            pandas.Series or None: A Series containing product details if found,
                                   otherwise None.
        """
        query = f"""
        SELECT id, name, category, brand, retail_price
        FROM `{self.project_id}.{self.dataset_id}.product_embeddings_clean`
        WHERE id = {product_id}
        """
        result = bpd.read_gbq(query)
        return result.to_pandas().iloc[0] if result.shape[0] > 0 else None

    def semantic_recommendations(self, product_id, top_k=5):
        """
        Generate recommendations based purely on semantic similarity.

        Finds products with the highest cosine similarity to the embedding of
        the target product.

        Args:
            product_id (int): The ID of the product for which to generate recommendations.
            top_k (int): The number of top recommendations to return.

        Returns:
            pandas.DataFrame: A DataFrame containing semantic recommendations.
        """
        query = f"""
        WITH target AS (
            SELECT embedding, name as target_name, category, brand, retail_price
            FROM `{self.project_id}.{self.dataset_id}.product_embeddings_clean`
            WHERE id = {product_id}
        )
        SELECT
            p.id, p.name, p.category, p.brand, p.retail_price,
            t.target_name,
            ROUND((1 - COSINE_DISTANCE(t.embedding, p.embedding)), 4) AS semantic_similarity,
            'Pure Semantic' as algorithm_type
        FROM `{self.project_id}.{self.dataset_id}.product_embeddings_clean` p
        CROSS JOIN target t
        WHERE p.id != {product_id}
        ORDER BY semantic_similarity DESC
        LIMIT {top_k}
        """
        return bpd.read_gbq(query).to_pandas()

    def hybrid_recommendations(self, product_id, top_k=5, semantic_weight=0.6, price_weight=0.25, brand_weight=0.1, category_weight=0.05):
        """
        Generate hybrid recommendations combining semantic similarity with product attributes.

        Uses customizable weights for semantic similarity, price similarity, brand match,
        and category match to calculate a hybrid score.

        Args:
            product_id (int): The ID of the product for which to generate recommendations.
            top_k (int): The number of top recommendations to return.
            semantic_weight (float): Weight for semantic similarity.
            price_weight (float): Weight for price similarity.
            brand_weight (float): Weight for brand match.
            category_weight (float): Weight for category match.

        Returns:
            pandas.DataFrame: A DataFrame containing hybrid recommendations with hybrid scores and explanations.
        """
        query = f"""
        WITH target AS (
            SELECT embedding, name as target_name, category, brand, retail_price
            FROM `{self.project_id}.{self.dataset_id}.product_embeddings_clean`
            WHERE id = {product_id}
        ),
        hybrid_scores AS (
            SELECT
                p.id, p.name, p.category, p.brand, p.retail_price,
                t.target_name,
                -- Individual scores
                ROUND((1 - COSINE_DISTANCE(t.embedding, p.embedding)), 4) AS semantic_sim,
                ROUND(1 - (ABS(p.retail_price - t.retail_price) / GREATEST(p.retail_price, t.retail_price)), 4) AS price_sim,
                CASE WHEN p.brand = t.brand THEN 1.0 ELSE 0.0 END AS brand_match,
                CASE WHEN p.category = t.category THEN 1.0 ELSE 0.0 END AS category_match,

                -- Hybrid score
                ROUND(
                    (1 - COSINE_DISTANCE(t.embedding, p.embedding)) * {semantic_weight} +
                    (1 - ABS(p.retail_price - t.retail_price) / GREATEST(p.retail_price, t.retail_price)) * {price_weight} +
                    CASE WHEN p.brand = t.brand THEN {brand_weight} ELSE 0 END +
                    CASE WHEN p.category = t.category THEN {category_weight} ELSE 0 END, 4
                ) AS hybrid_score,

                -- Explanation
                CASE
                    WHEN p.brand = t.brand AND p.category = t.category THEN 'Perfect Match (Same Brand & Category)'
                    WHEN p.brand = t.brand THEN 'Brand Loyalty Match'
                    WHEN p.category = t.category THEN 'Category Match'
                    WHEN ABS(p.retail_price - t.retail_price) / t.retail_price < 0.15 THEN 'Price Point Match'
                    ELSE 'AI Semantic Discovery'
                END as match_explanation

            FROM `{self.project_id}.{self.dataset_id}.product_embeddings_clean` p
            CROSS JOIN target t
            WHERE p.id != {product_id}
        )
        SELECT *, 'Hybrid AI' as algorithm_type
        FROM hybrid_scores
        ORDER BY hybrid_score DESC
        LIMIT {top_k}
        """
        return bpd.read_gbq(query).to_pandas()

    def business_smart_recommendations(self, product_id, top_k=5):
        """
        Generate business-optimized recommendations considering profit margins.

        Combines semantic similarity with a bonus for products with higher profit margins.

        Args:
            product_id (int): The ID of the product for which to generate recommendations.
            top_k (int): The number of top recommendations to return.

        Returns:
            pandas.DataFrame: A DataFrame containing business-optimized recommendations with business scores and tiers.
        """
        query = f"""
        WITH target AS (
            SELECT p.embedding, p.name as target_name, p.category, p.brand, p.retail_price,
                   orig.cost
            FROM `{self.project_id}.{self.dataset_id}.product_embeddings_clean` p
            LEFT JOIN `bigquery-public-data.thelook_ecommerce.products` orig ON p.id = orig.id
            WHERE p.id = {product_id}
        ),
        business_recs AS (
            SELECT
                p.id, p.name, p.category, p.brand, p.retail_price,
                orig.cost,
                CASE WHEN orig.cost IS NOT NULL THEN
                    ROUND((orig.retail_price - orig.cost) / orig.retail_price * 100, 1)
                    ELSE NULL END as margin_pct,
                ROUND((1 - COSINE_DISTANCE(t.embedding, p.embedding)), 4) AS semantic_similarity,

                -- Business score (higher margin products get bonus)
                ROUND(
                    (1 - COSINE_DISTANCE(t.embedding, p.embedding)) * 0.7 +
                    CASE WHEN orig.cost IS NOT NULL AND (orig.retail_price - orig.cost) / orig.retail_price > 0.4
                         THEN 0.3 ELSE 0.1 END, 4
                ) AS business_score,

                CASE
                    WHEN orig.cost IS NOT NULL AND (orig.retail_price - orig.cost) / orig.retail_price > 0.5
                        THEN 'High Profit Recommendation'
                    WHEN orig.cost IS NOT NULL AND (orig.retail_price - orig.cost) / orig.retail_price > 0.3
                        THEN 'Good Profit Recommendation'
                    ELSE 'Standard Recommendation'
                END as business_tier

            FROM `{self.project_id}.{self.dataset_id}.product_embeddings_clean` p
            LEFT JOIN `bigquery-public-data.thelook_ecommerce.products` orig ON p.id = orig.id
            CROSS JOIN target t
            WHERE p.id != {product_id}
        )
        SELECT *, 'Business Smart' as algorithm_type
        FROM business_recs
        ORDER BY business_score DESC
        LIMIT {top_k}
        """
        return bpd.read_gbq(query).to_pandas()

    def comprehensive_recommendation_comparison(self, product_id):
        """
        Compare recommendations generated by all algorithms side by side.

        Generates and prints recommendations from the semantic, hybrid, and business
        algorithms for a given product, allowing for easy comparison of their outputs.

        Args:
            product_id (int): The ID of the product for which to compare recommendations.

        Returns:
            dict: A dictionary where keys are algorithm names and values are
                  pandas DataFrames containing the recommendation results,
                  or None if the product is not found.
        """
        product_info = self.get_product_info(product_id)
        if product_info is None:
            return None

        print(f"COMPREHENSIVE RECOMMENDATIONS FOR:")
        print(f"   Product: {product_info['name']}")
        print(f"   Category: {product_info['category']} | Brand: {product_info['brand']} | Price: ${product_info['retail_price']:.2f}")
        print("=" * 100)

        # Get recommendations from all algorithms
        algorithms = {
            'Semantic': self.semantic_recommendations(product_id, 3),
            'Hybrid': self.hybrid_recommendations(product_id, 3),
            'Business': self.business_smart_recommendations(product_id, 3)
        }

        for algo_name, recs in algorithms.items():
            print(f"\n{algo_name} RECOMMENDATIONS:")
            print("-" * 50)
            for i, (_, row) in enumerate(recs.iterrows(), 1):
                print(f"  {i}. {row['name'][:50]}...")
                print(f"     Category: {row['category']} | Brand: {row['brand']} | Price: ${row['retail_price']:.2f}")

                # Algorithm-specific scores
                if 'semantic_similarity' in row:
                    score = row.get('hybrid_score', row.get('business_score', row['semantic_similarity']))
                    print(f"     Score: {score:.3f}", end="")
                    if 'match_explanation' in row:
                        print(f" | {row['match_explanation']}")
                    elif 'business_tier' in row:
                        print(f" | {row['business_tier']}")
                    else:
                        print(" | Semantic Similarity")

        return algorithms

# %% [markdown]
# # Interactive Visualization Dashboard

# %%
class InteractiveVisualizationDashboard:
    """
    Create beautiful, interactive visualizations for vector search insights.

    This class provides methods to generate visual dashboards and charts
    based on product data and vector similarity analysis.
    """

    def __init__(self, project_id, dataset_id):
        """
        Initializes the InteractiveVisualizationDashboard.

        Args:
            project_id (str): The Google Cloud Project ID.
            dataset_id (str): The BigQuery dataset ID containing product data.
        """
        self.project_id = project_id
        self.dataset_id = dataset_id

    def create_similarity_heatmap(self, sample_products=None):
        """
        Create a similarity heatmap for a set of products.

        Visualizes the pairwise semantic similarity between a sample of products
        using a heatmap. If no sample products are provided, a diverse sample
        is automatically selected.

        Args:
            sample_products (list, optional): A list of product IDs to include
                                               in the heatmap. Defaults to None.

        Returns:
            plotly.graph_objects.Figure: The generated Plotly heatmap figure.
        """
        if sample_products is None:
            # Get a diverse sample of products
            sample_query = f"""
            SELECT DISTINCT id, name, category
            FROM `{self.project_id}.{self.dataset_id}.product_embeddings_clean`
            ORDER BY RAND()
            LIMIT 8
            """
            sample_products = bpd.read_gbq(sample_query).to_pandas()['id'].tolist()

        # Get similarity matrix
        products_str = ','.join(map(str, sample_products[:8]))  # Limit to 8 for readability

        similarity_query = f"""
        WITH sample_products AS (
            SELECT id, name, embedding
            FROM `{self.project_id}.{self.dataset_id}.product_embeddings_clean`
            WHERE id IN ({products_str})
        )
        SELECT
            p1.id as product1_id,
            p1.name as product1_name,
            p2.id as product2_id,
            p2.name as product2_name,
            ROUND((1 - COSINE_DISTANCE(p1.embedding, p2.embedding)), 3) AS similarity
        FROM sample_products p1
        CROSS JOIN sample_products p2
        """

        similarity_data = bpd.read_gbq(similarity_query).to_pandas()

        # Create pivot table for heatmap
        pivot_table = similarity_data.pivot(index='product1_name', columns='product2_name', values='similarity')

        # Create interactive heatmap
        fig = px.imshow(
            pivot_table.values,
            x=[name[:20] + '...' if len(name) > 20 else name for name in pivot_table.columns],
            y=[name[:20] + '...' if len(name) > 20 else name for name in pivot_table.index],
            color_continuous_scale='RdYlBu_r',
            title='Product Similarity Heatmap (Cosine Similarity)',
            labels={'color': 'Similarity Score'}
        )

        fig.update_layout(
            width=800, height=600,
            title_x=0.5,
            xaxis_title="Products",
            yaxis_title="Products"
        )

        fig.show()
        return fig

    def create_category_performance_dashboard(self):
        """
        Create a comprehensive category performance visualization dashboard.

        Generates a subplot dashboard including charts for products per category,
        average price by category, brand diversity vs. product count, and
        average profit margins by category (where cost data is available).

        Returns:
            plotly.graph_objects.Figure: The generated Plotly subplot figure.
        """

        # Get category data
        category_query = f"""
        WITH category_metrics AS (
            SELECT
                p.category,
                COUNT(*) as product_count,
                AVG(p.retail_price) as avg_price,
                MIN(p.retail_price) as min_price,
                MAX(p.retail_price) as max_price,
                COUNT(DISTINCT p.brand) as unique_brands,
                AVG(orig.cost) as avg_cost,
                AVG(CASE WHEN orig.cost IS NOT NULL
                    THEN (orig.retail_price - orig.cost) / orig.retail_price
                    ELSE NULL END) as avg_margin
            FROM `{self.project_id}.{self.dataset_id}.product_embeddings_clean` p
            LEFT JOIN `bigquery-public-data.thelook_ecommerce.products` orig ON p.id = orig.id
            GROUP BY p.category
        )
        SELECT *,
            CASE
                WHEN avg_margin > 0.5 THEN 'High Profit'
                WHEN avg_margin > 0.3 THEN 'Good Profit'
                WHEN avg_margin > 0.15 THEN 'Average Profit'
                ELSE 'Low Profit'
            END as profit_tier
        FROM category_metrics
        ORDER BY product_count DESC
        """

        category_data = bpd.read_gbq(category_query).to_pandas()

        # Create subplot dashboard
        fig = make_subplots(
            rows=2, cols=2,
            subplot_titles=(
                'Products per Category',
                'Average Price by Category',
                'Brand Diversity',
                'Profit Margins'
            ),
            specs=[[{"type": "bar"}, {"type": "bar"}],
                   [{"type": "scatter"}, {"type": "bar"}]]
        )

        # Top 10 categories for readability
        top_categories = category_data.head(10)

        # Product count
        fig.add_trace(
            go.Bar(x=top_categories['category'], y=top_categories['product_count'],
                   name="Product Count", marker_color='lightblue'),
            row=1, col=1
        )

        # Average price
        fig.add_trace(
            go.Bar(x=top_categories['category'], y=top_categories['avg_price'],
                   name="Avg Price", marker_color='lightcoral'),
            row=1, col=2
        )

        # Brand diversity vs product count
        fig.add_trace(
            go.Scatter(x=top_categories['product_count'], y=top_categories['unique_brands'],
                      mode='markers+text', text=top_categories['category'],
                      textposition='top center', name="Brand Diversity",
                      marker=dict(size=10, color='green')),
            row=2, col=1
        )

        # Profit margins (where available)
        margin_data = top_categories[top_categories['avg_margin'].notna()]
        if not margin_data.empty:
            fig.add_trace(
                go.Bar(x=margin_data['category'], y=margin_data['avg_margin']*100,
                       name="Profit Margin %", marker_color='gold'),
                row=2, col=2
            )

        fig.update_layout(
            height=800,
            title_text="E-Commerce Category Performance Dashboard",
            title_x=0.5,
            showlegend=False
        )

        # Update subplot titles
        fig.update_xaxes(tickangle=45)

        fig.show()
        return fig

    def visualize_recommendation_quality(self, product_id, algorithms_results):
        """
        Visualize recommendation quality across different algorithms for a product.

        Creates a bar chart comparing the recommendation scores generated by
        different algorithms for a specific product, providing insights into
        their performance and the reasons behind the scores.

        Args:
            product_id (int): The ID of the product for which recommendations
                              are being visualized.
            algorithms_results (dict): A dictionary where keys are algorithm names
                                       and values are pandas DataFrames containing
                                       recommendation results (including scores).

        Returns:
            plotly.graph_objects.Figure: The generated Plotly bar chart figure.
        """

        # Prepare data for visualization
        all_scores = []
        for algo_name, recs_df in algorithms_results.items():
            for _, row in recs_df.iterrows():
                score_col = 'hybrid_score' if 'hybrid_score' in row else \
                           'business_score' if 'business_score' in row else 'semantic_similarity'

                explanation = ""
                if 'match_explanation' in row:
                  explanation = row['match_explanation']
                elif 'business_tier' in row:
                  explanation = row['business_tier']

                all_scores.append({
                    'Algorithm': algo_name,
                    'Product': row['name'][:30] + '...' if len(row['name']) > 30 else row['name'],
                    'Score': row[score_col],
                    'Category': row['category'],
                    'Price': row['retail_price'],
                    'Explanation': explanation # Include explanation for hover info
                })

        scores_df = pd.DataFrame(all_scores)

        # Create comparison chart
        fig = px.bar(
            scores_df,
            x='Product',
            y='Score',
            color='Algorithm',
            title=f'Recommendation Quality Comparison for Product {product_id}',
            hover_data=['Category', 'Price', 'Explanation'] # Add Explanation to hover data
        )

        fig.update_layout(
            width=1000, height=500,
            title_x=0.5,
            xaxis_tickangle=45
        )

        fig.show()
        return fig

# %% [markdown]
# # Business Intelligence & Analytics Engine

# %%
class BusinessIntelligenceEngine:
    """
    Advanced business analytics using vector search insights.

    This class provides methods to analyze product data, identify cross-selling
    and pricing opportunities, generate product clustering insights, and
    analyze brand positioning using vector embeddings.
    """

    def __init__(self, project_id, dataset_id):
        """
        Initializes the BusinessIntelligenceEngine.

        Args:
            project_id (str): The Google Cloud Project ID.
            dataset_id (str): The BigQuery dataset ID containing product data.
        """
        self.project_id = project_id
        self.dataset_id = dataset_id

    def analyze_cross_selling_opportunities(self):
        """
        Find the best cross-selling opportunities using semantic similarity.

        Identifies pairs of products from different categories that have high
        semantic similarity, suggesting potential cross-selling bundles.

        Returns:
            pandas.DataFrame: A DataFrame listing potential cross-selling pairs
                              with their semantic affinity and potential bundle value.
        """
        query = f"""
        WITH cross_sell_analysis AS (
            SELECT
                p1.category as primary_category,
                p2.category as cross_sell_category,
                COUNT(*) as similar_product_pairs,
                AVG((1 - COSINE_DISTANCE(p1.embedding, p2.embedding))) as avg_similarity,
                AVG(p1.retail_price) as avg_primary_price,
                AVG(p2.retail_price) as avg_cross_sell_price,
                AVG(p1.retail_price + p2.retail_price) as avg_bundle_value
            FROM `{self.project_id}.{self.dataset_id}.product_embeddings_clean` p1
            CROSS JOIN `{self.project_id}.{self.dataset_id}.product_embeddings_clean` p2
            WHERE p1.category != p2.category
              AND (1 - COSINE_DISTANCE(p1.embedding, p2.embedding)) > 0.4
            GROUP BY p1.category, p2.category
            HAVING COUNT(*) >= 10  -- Ensure statistical significance
        )
        SELECT
            primary_category,
            cross_sell_category,
            similar_product_pairs,
            ROUND(avg_similarity, 3) as semantic_affinity,
            ROUND(avg_primary_price, 2) as avg_primary_price,
            ROUND(avg_cross_sell_price, 2) as avg_cross_sell_price,
            ROUND(avg_bundle_value, 2) as potential_bundle_value,
            CASE
                WHEN avg_similarity > 0.6 THEN 'Excellent Cross-Sell'
                WHEN avg_similarity > 0.5 THEN 'Good Cross-Sell'
                ELSE 'Moderate Cross-Sell'
            END as opportunity_rating
        FROM cross_sell_analysis
        ORDER BY avg_similarity DESC, similar_product_pairs DESC
        LIMIT 20
        """

        return bpd.read_gbq(query).to_pandas()

    def identify_pricing_opportunities(self):
        """
        Identify products that could be repriced based on similar product analysis.

        Compares a product's current price to the average price of semantically
        similar products within the same category to identify potential under-
        or over-priced items.

        Returns:
            pandas.DataFrame: A DataFrame listing products with pricing recommendations
                              based on market comparison.
        """
        query = f"""
        WITH similar_products_analysis AS (
            SELECT
                p1.id as product_id,
                p1.retail_price as current_price,
                p2.retail_price as similar_price,
                (1 - COSINE_DISTANCE(p1.embedding, p2.embedding)) as similarity_score
            FROM `{self.project_id}.{self.dataset_id}.product_embeddings_clean` p1
            JOIN `{self.project_id}.{self.dataset_id}.product_embeddings_clean` p2
              ON p1.category = p2.category AND p1.id != p2.id
            WHERE (1 - COSINE_DISTANCE(p1.embedding, p2.embedding)) > 0.6
              AND ABS(p2.retail_price - p1.retail_price) / p1.retail_price < 0.5
        ),
        pricing_analysis AS (
            SELECT
                product_id,
                ANY_VALUE(current_price) as current_price,
                AVG(similar_price) as market_avg_price,
                COUNT(similar_price) as similar_products_count
            FROM similar_products_analysis
            GROUP BY product_id
            HAVING COUNT(similar_price) >= 3
        )
        SELECT
            p.id,
            p.name,
            p.category,
            p.brand,
            ROUND(pa.current_price, 2) as current_price,
            ROUND(pa.market_avg_price, 2) as market_avg_price,
            pa.similar_products_count,
            ROUND(pa.market_avg_price - pa.current_price, 2) as price_gap,
            ROUND((pa.market_avg_price - pa.current_price) / pa.current_price * 100, 1) as price_gap_percent,
            CASE
                WHEN pa.market_avg_price > pa.current_price * 1.15 THEN 'Under-priced (Increase Opportunity)'
                WHEN pa.market_avg_price < pa.current_price * 0.85 THEN 'Over-priced (Decrease Risk)'
                ELSE 'Well-priced'
            END as pricing_recommendation,
            CASE
                WHEN pa.similar_products_count >= 10 THEN 'High Confidence'
                WHEN pa.similar_products_count >= 5 THEN 'Medium Confidence'
                ELSE 'Low Confidence'
            END as confidence_level
        FROM pricing_analysis pa
        JOIN `{self.project_id}.{self.dataset_id}.product_embeddings_clean` p ON pa.product_id = p.id
        ORDER BY ABS(price_gap_percent) DESC
        LIMIT 30
        """

        return bpd.read_gbq(query).to_pandas()

    def generate_product_clustering_insights(self):
        """
        Generate advanced product clustering insights based on vector embeddings.

        Identifies products that are semantically similar to products in different
        categories, suggesting cross-category appeal or potential miscategorization.

        Returns:
            pandas.DataFrame: A DataFrame listing products with their most similar
                              cross-category matches and a market positioning assessment.
        """
        query = f"""
        WITH product_similarities AS (
            SELECT
                p1.id as product_id,
                p1.name,
                p1.category,
                p1.brand,
                p1.retail_price,
                -- Find the most similar product that's NOT in the same category
                ARRAY_AGG(
                    STRUCT(
                        p2.id as similar_id,
                        p2.name as similar_name,
                        p2.category as similar_category,
                        (1 - COSINE_DISTANCE(p1.embedding, p2.embedding)) as similarity
                    )
                    ORDER BY (1 - COSINE_DISTANCE(p1.embedding, p2.embedding)) DESC
                    LIMIT 3
                )[OFFSET(0)] as most_similar_different_category
            FROM `{self.project_id}.{self.dataset_id}.product_embeddings_clean` p1
            CROSS JOIN `{self.project_id}.{self.dataset_id}.product_embeddings_clean` p2
            WHERE p1.id != p2.id
              AND p1.category != p2.category
              AND (1 - COSINE_DISTANCE(p1.embedding, p2.embedding)) > 0.3
            GROUP BY p1.id, p1.name, p1.category, p1.brand, p1.retail_price
        )
        SELECT
            product_id,
            name as product_name,
            category as product_category, -- Corrected alias here
            brand,
            retail_price,
            most_similar_different_category.similar_name as cross_category_match,
            most_similar_different_category.similar_category as match_category,
            ROUND(most_similar_different_category.similarity, 3) as cross_category_similarity,
            CASE
                WHEN most_similar_different_category.similarity > 0.7 THEN 'Strong Cross-Category Appeal'
                WHEN most_similar_different_category.similarity > 0.5 THEN 'Moderate Cross-Category Appeal'
                ELSE 'Category-Specific'
            END as market_positioning
        FROM product_similarities
        WHERE most_similar_different_category IS NOT NULL
        ORDER BY most_similar_different_category.similarity DESC
        LIMIT 25
        """

        return bpd.read_gbq(query).to_pandas()

    def analyze_brand_positioning(self):
        """
        Analyze how brands position themselves in the semantic space.

        Compares the semantic similarity of products across different brands
        to understand competitive landscapes and price positioning within the market.

        Returns:
            pandas.DataFrame: A DataFrame summarizing brand positioning based on
                              market similarity, price point, and competitive landscape.
        """
        query = f"""
        WITH brand_analysis AS (
            SELECT
                p1.brand,
                p2.brand as competitor_brand,
                COUNT(*) as similar_product_pairs,
                AVG((1 - COSINE_DISTANCE(p1.embedding, p2.embedding))) as avg_similarity,
                AVG(p1.retail_price) as avg_brand_price,
                AVG(p2.retail_price) as avg_competitor_price
            FROM `{self.project_id}.{self.dataset_id}.product_embeddings_clean` p1
            CROSS JOIN `{self.project_id}.{self.dataset_id}.product_embeddings_clean` p2
            WHERE p1.brand != p2.brand
              AND (1 - COSINE_DISTANCE(p1.embedding, p2.embedding)) > 0.5
            GROUP BY p1.brand, p2.brand
            HAVING COUNT(*) >= 5
        ),
        brand_metrics AS (
            SELECT
                brand,
                COUNT(DISTINCT competitor_brand) as competing_brands,
                AVG(avg_similarity) as overall_market_similarity,
                AVG(avg_brand_price) as brand_price_point,
                AVG(similar_product_pairs) as avg_competing_products
            FROM brand_analysis
            GROUP BY brand
        )
        SELECT
            brand,
            competing_brands,
            ROUND(overall_market_similarity, 3) as market_similarity_score,
            ROUND(brand_price_point, 2) as avg_price_point,
            ROUND(avg_competing_products, 1) as avg_competing_products,
            CASE
                WHEN overall_market_similarity > 0.65 THEN 'Highly Competitive Space'
                WHEN overall_market_similarity > 0.55 THEN 'Moderate Competition'
                ELSE 'Niche Positioning'
            END as competitive_landscape,
            CASE
                WHEN brand_price_point > 75 THEN 'Premium Brand'
                WHEN brand_price_point > 35 THEN 'Mid-Market Brand'
                ELSE 'Value Brand'
            END as price_positioning
        FROM brand_metrics
        WHERE competing_brands >= 3
        ORDER BY overall_market_similarity DESC, competing_brands DESC
        LIMIT 20
        """

        return bpd.read_gbq(query).to_pandas()

    def generate_executive_summary(self):
        """
        Generate a comprehensive executive summary of business intelligence insights.

        Provides a high-level overview of key metrics, top cross-selling
        opportunities, pricing insights, and brand positioning analysis.

        Returns:
            dict: A dictionary containing summary metrics.
        """
        print("EXECUTIVE BUSINESS INTELLIGENCE SUMMARY")
        print("=" * 60)

        # Get key metrics
        total_products_query = f"SELECT COUNT(*) as total FROM `{self.project_id}.{self.dataset_id}.product_embeddings_clean`"
        total_products = bpd.read_gbq(total_products_query).to_pandas().iloc[0]['total']

        categories_query = f"SELECT COUNT(DISTINCT category) as categories FROM `{self.project_id}.{self.dataset_id}.product_embeddings_clean`"
        total_categories = bpd.read_gbq(categories_query).to_pandas().iloc[0]['categories']

        brands_query = f"SELECT COUNT(DISTINCT brand) as brands FROM `{self.project_id}.{self.dataset_id}.product_embeddings_clean`"
        total_brands = bpd.read_gbq(brands_query).to_pandas().iloc[0]['brands']

        print(f"PORTFOLIO OVERVIEW:")
        print(f"Total Products: {total_products:,}")
        print(f"Categories: {total_categories}")
        print(f"Brands: {total_brands}")

        # Analyze cross-selling opportunities
        cross_sell = self.analyze_cross_selling_opportunities()
        print(f"\nTOP CROSS-SELLING OPPORTUNITIES:")
        for i, (_, row) in enumerate(cross_sell.head(3).iterrows(), 1):
            print(f"   {i}. {row['primary_category']} ↔ {row['cross_sell_category']}")
            print(f"      Semantic Affinity: {row['semantic_affinity']:.3f} | Bundle Value: ${row['potential_bundle_value']:.2f}")

        # Analyze pricing opportunities
        pricing = self.identify_pricing_opportunities()
        underpriced = pricing[pricing['pricing_recommendation'].str.contains('Under-priced')]
        overpriced = pricing[pricing['pricing_recommendation'].str.contains('Over-priced')]

        print(f"\nPRICING INSIGHTS:")
        print(f" Under-priced Products: {len(underpriced)}")
        print(f" Over-priced Products: {len(overpriced)}")
        if len(underpriced) > 0:
            avg_increase_opportunity = underpriced['price_gap_percent'].mean()
            print(f"   • Avg. Price Increase Opportunity: {avg_increase_opportunity:.1f}%")

        # Brand positioning insights
        brand_pos = self.analyze_brand_positioning()
        premium_brands = len(brand_pos[brand_pos['price_positioning'] == 'Premium Brand'])
        value_brands = len(brand_pos[brand_pos['price_positioning'] == 'Value Brand'])

        print(f"\nBRAND POSITIONING:")
        print(f" Premium Brands: {premium_brands}")
        print(f" Value Brands: {value_brands}")
        print(f" Most Competitive Space: {brand_pos.iloc[0]['brand']} (Score: {brand_pos.iloc[0]['market_similarity_score']})")

        return {
            'total_products': total_products,
            'cross_sell_opportunities': len(cross_sell),
            'pricing_opportunities': len(underpriced) + len(overpriced),
            'brand_insights': len(brand_pos)
        }

# %% [markdown]
# # Advanced Search & Discovery Features

# %%
class AdvancedSearchDiscovery:
    """
    Next-generation search and discovery features using vector embeddings.

    This class provides methods for semantic trend analysis, identifying market
    gaps, generating intelligent bundle suggestions, and enabling personalized
    product discovery.
    """

    def __init__(self, project_id, dataset_id):
        """
        Initializes the AdvancedSearchDiscovery.

        Args:
            project_id (str): The Google Cloud Project ID.
            dataset_id (str): The BigQuery dataset ID containing product data.
        """
        self.project_id = project_id
        self.dataset_id = dataset_id

    def semantic_trend_analysis(self, category=None):
        """
        Analyze trends in product semantics within categories or across all products.

        Calculates the average intra-category semantic similarity and analyzes
        brand performance within categories based on product count, average price,
        and semantic coherence.

        Args:
            category (str, optional): The specific category to analyze. If None,
                                      analyzes trends across all categories.
                                      Defaults to None.

        Returns:
            pandas.DataFrame: A DataFrame summarizing semantic trends and brand
                              focus strategies within categories.
        """
        category_filter = f"AND t1.category = '{category}'" if category else ""

        query = f"""
        WITH category_avg_similarity AS (
            SELECT
                p1.category,
                AVG((1 - COSINE_DISTANCE(p1.embedding, p2.embedding))) as avg_intra_category_similarity
            FROM `{self.project_id}.{self.dataset_id}.product_embeddings_clean` p1
            JOIN `{self.project_id}.{self.dataset_id}.product_embeddings_clean` p2
              ON p1.category = p2.category AND p1.id != p2.id
            GROUP BY p1.category
        ),
        brand_metrics AS (
            SELECT
                p.category,
                p.brand,
                COUNT(*) as product_count,
                AVG(p.retail_price) as avg_price
            FROM `{self.project_id}.{self.dataset_id}.product_embeddings_clean` p
            WHERE TRUE {category_filter}
            GROUP BY p.category, p.brand
            HAVING COUNT(*) >= 3
        )
        SELECT
            bm.category,
            bm.brand,
            bm.product_count,
            ROUND(bm.avg_price, 2) as avg_price,
            ROUND(cas.avg_intra_category_similarity, 3) as semantic_coherence,
            CASE
                WHEN cas.avg_intra_category_similarity > 0.6 THEN 'Highly Focused Brand'
                WHEN cas.avg_intra_category_similarity > 0.4 THEN 'Moderately Focused'
                ELSE 'Diverse Portfolio'
            END as brand_focus_strategy
        FROM brand_metrics bm
        JOIN category_avg_similarity cas ON bm.category = cas.category
        ORDER BY semantic_coherence DESC, product_count DESC
        LIMIT 25
        """

        return bpd.read_gbq(query).to_pandas()

    def find_market_gaps(self):
        """
        Identify potential market gaps using semantic analysis.

        Analyzes the semantic distance and price difference between category
        centroids to identify areas in the product space that are less covered
        or have significant price disparities, suggesting potential market gaps.

        Returns:
            pandas.DataFrame: A DataFrame listing potential market gaps between
                              categories with their semantic and price distances,
                              and an opportunity assessment.
        """
        query = f"""
        WITH category_embeddings AS (
            SELECT
                category,
                -- Calculate category centroid (average embedding) by unnesting
                ARRAY(
                    SELECT AVG(dim_value)
                    FROM (
                        SELECT embedding, GENERATE_ARRAY(0, ARRAY_LENGTH(embedding)-1) as positions
                        FROM `{self.project_id}.{self.dataset_id}.product_embeddings_clean`
                    ),
                    UNNEST(positions) as pos WITH OFFSET
                    CROSS JOIN UNNEST([embedding[SAFE_OFFSET(pos)]]) as dim_value
                    GROUP BY pos
                    ORDER BY pos
                ) as avg_embedding,
                COUNT(*) as product_count,
                AVG(retail_price) as avg_price
            FROM
                `{self.project_id}.{self.dataset_id}.product_embeddings_clean`,
                UNNEST(embedding) as value WITH OFFSET index
            GROUP BY category
            HAVING COUNT(*) >= 10
        ),
        category_distances AS (
            SELECT
                c1.category as category1,
                c2.category as category2,
                -- Use COSINE_DISTANCE for semantic similarity between centroids
                ROUND((1 - COSINE_DISTANCE(c1.avg_embedding, c2.avg_embedding)), 3) as semantic_similarity,
                ABS(c1.avg_price - c2.avg_price) as price_distance,
                c1.product_count as cat1_products,
                c2.product_count as cat2_products
            FROM category_embeddings c1
            CROSS JOIN category_embeddings c2
            WHERE c1.category != c2.category
        )
        SELECT
            category1,
            category2,
            -- Rename semantic_similarity to semantic_gap for consistency with original output
            semantic_similarity as semantic_gap,
            ROUND(price_distance, 2) as price_gap,
            cat1_products + cat2_products as total_products,
            CASE
                WHEN semantic_similarity < 0.35 AND price_distance > 30 THEN 'High Potential Gap' -- Lower similarity indicates a gap
                WHEN semantic_similarity < 0.5 AND price_distance > 20 THEN 'Moderate Gap'
                ELSE 'Low Priority Gap'
            END as market_opportunity
        FROM category_distances
        WHERE semantic_similarity BETWEEN 0.05 AND 0.6  -- Adjusted range for similarity (lower is gap)
        ORDER BY semantic_similarity ASC, price_distance DESC -- Order by lowest similarity first for gaps
        LIMIT 15
        """

        return bpd.read_gbq(query).to_pandas()

    def intelligent_bundle_suggestions(self, max_bundle_price=200):
        """
        Generate intelligent product bundles based on semantic similarity and business rules.

        Identifies pairs of products from different categories that are semantically
        similar and fall within a specified maximum bundle price, suggesting
        potential product bundles with a compatibility score and suggested discount.

        Args:
            max_bundle_price (int): The maximum combined price for suggested bundles.
                                    Defaults to 200.

        Returns:
            pandas.DataFrame: A DataFrame listing intelligent bundle suggestions
                              with product details, compatibility score, and
                              suggested discount.
        """
        query = f"""
        WITH bundle_candidates AS (
            SELECT
                p1.id as product1_id,
                p1.name as product1_name,
                p1.category as product1_category,
                p1.retail_price as product1_price,
                p2.id as product2_id,
                p2.name as product2_name,
                p2.category as product2_category,
                p2.retail_price as product2_price,
                (1 - COSINE_DISTANCE(p1.embedding, p2.embedding)) as similarity,
                p1.retail_price + p2.retail_price as bundle_price
            FROM `{self.project_id}.{self.dataset_id}.product_embeddings_clean` p1
            CROSS JOIN `{self.project_id}.{self.dataset_id}.product_embeddings_clean` p2
            WHERE p1.id < p2.id  -- Avoid duplicates
              AND p1.category != p2.category  -- Cross-category bundles
              AND (1 - COSINE_DISTANCE(p1.embedding, p2.embedding)) > 0.4
              AND p1.retail_price + p2.retail_price <= {max_bundle_price}
        )
        SELECT
            product1_name,
            product1_category,
            ROUND(product1_price, 2) as product1_price,
            product2_name,
            product2_category,
            ROUND(product2_price, 2) as product2_price,
            ROUND(bundle_price, 2) as bundle_price,
            ROUND(similarity, 3) as compatibility_score,
            CASE
                WHEN similarity > 0.7 THEN 'Perfect Bundle'
                WHEN similarity > 0.6 THEN 'Great Bundle'
                WHEN similarity > 0.5 THEN 'Good Bundle'
                ELSE 'Moderate Bundle'
            END as bundle_quality,
            -- Suggested discount
            ROUND(bundle_price * 0.1, 2) as suggested_discount,
            ROUND(bundle_price * 0.9, 2) as discounted_price
        FROM bundle_candidates
        ORDER BY similarity DESC, bundle_price ASC
        LIMIT 20
        """

        return bpd.read_gbq(query).to_pandas()

    def personalized_discovery_engine(self, user_preferences):
      """
      Advanced personalized product discovery based on user preferences.

      Simulates personalized recommendations by calculating a user profile
      centroid based on preferred categories and price ranges, and then
      finding products semantically similar to that profile.

      Args:
          user_preferences (dict): A dictionary containing user preferences,
                                   e.g., {'preferred_category': 'Jeans',
                                         'price_range': [20, 80]}.

      Returns:
          pandas.DataFrame: A DataFrame listing personalized product recommendations
                            with their recommendation score and type.
      """
      # This would typically use user behavior data, but we'll simulate with preferences
      category_pref = user_preferences.get('preferred_category', 'Jeans')
      price_range = user_preferences.get('price_range', [20, 80])

      # Calculate expanded price range for recommendations
      min_price = price_range[0] * 0.7
      max_price = price_range[1] * 1.3

      query = f"""
      WITH user_profile AS (
          SELECT
              -- Calculate centroid by averaging each dimension
              ARRAY(
                  SELECT AVG(dim_value)
                  FROM (
                      SELECT embedding, GENERATE_ARRAY(0, ARRAY_LENGTH(embedding)-1) as positions
                      FROM `{self.project_id}.{self.dataset_id}.product_embeddings_clean`
                      WHERE category = '{category_pref}' AND retail_price BETWEEN {price_range[0]} AND {price_range[1]}
                  ),
                  UNNEST(positions) as pos WITH OFFSET
                  CROSS JOIN UNNEST([embedding[SAFE_OFFSET(pos)]]) as dim_value
                  GROUP BY pos
                  ORDER BY pos
              ) as avg_embedding
      ),
      personalized_scores AS (
          SELECT
              p.id,
              p.name,
              p.category,
              p.brand,
              p.retail_price,
              -- Calculate personalized similarity
              (1 - ML.DISTANCE(p.embedding, up.avg_embedding, 'COSINE')) as personalization_score,

              -- Diversity bonus for exploration
              CASE WHEN p.category != '{category_pref}' THEN 0.1 ELSE 0 END as diversity_bonus

          FROM `{self.project_id}.{self.dataset_id}.product_embeddings_clean` p
          CROSS JOIN user_profile up
          WHERE p.retail_price BETWEEN {min_price} AND {max_price}  -- Expanded range
      )
      SELECT
          name,
          category,
          brand,
          ROUND(retail_price, 2) as price,
          ROUND(personalization_score + diversity_bonus, 3) as recommendation_score,
          CASE
              WHEN category = '{category_pref}' THEN 'Perfect Match'
              WHEN personalization_score > 0.5 THEN 'Discovery Pick'
              ELSE 'Exploration Option'
          END as recommendation_type
      FROM personalized_scores
      WHERE personalization_score IS NOT NULL
      ORDER BY recommendation_score DESC
      LIMIT 15
      """

      return bpd.read_gbq(query).to_pandas()

# %% [markdown]
# # EXECUTION SECTION: Run All Analysis

# %%
def run_complete_analysis():
    """
    Execute the complete vector search analysis pipeline.

    Initializes all analysis components, loads product data, performs
    sample search, category insights, recommendation analysis, visualizations,
    business intelligence analysis (cross-selling, pricing, clustering, brand),
    and advanced search/discovery (trends, gaps, bundles, personalization).
    Prints key insights and returns initialized class instances and summary metrics.

    Returns:
        dict: A dictionary containing initialized instances of all analysis classes
              and a dictionary of summary metrics.
    """

    print("STARTING COMPREHENSIVE VECTOR SEARCH ANALYSIS")
    print("=" * 80)

    # Initialize all components
    explorer = SmartProductExplorer(PROJECT_ID, DATASET_ID)
    rec_engine = AdvancedRecommendationEngine(PROJECT_ID, DATASET_ID)
    viz_dashboard = InteractiveVisualizationDashboard(PROJECT_ID, DATASET_ID)
    bi_engine = BusinessIntelligenceEngine(PROJECT_ID, DATASET_ID)
    search_discovery = AdvancedSearchDiscovery(PROJECT_ID, DATASET_ID)

    # Load products and basic exploration
    print("\nLOADING PRODUCTS WITH INSIGHTS...")
    products = explorer.load_products_with_insights()

    # Interactive search example
    print("\nSMART SEARCH DEMO:")
    search_results = explorer.smart_search("jacket")
    print(search_results[['name', 'category', 'brand', 'price_tier', 'brand_tier']].head())

    print("\nCATEGORY INSIGHTS:")
    category_insights = explorer.get_category_insights()
    print(category_insights.head(10))

    # Recommendation analysis
    print("\nRECOMMENDATION ENGINE DEMO:")
    sample_product_id = 21018  # You can change this
    recommendations_comparison = rec_engine.comprehensive_recommendation_comparison(sample_product_id)

    # Visualizations
    print("\nCREATING INTERACTIVE VISUALIZATIONS...")
    try:
        similarity_heatmap = viz_dashboard.create_similarity_heatmap()
        category_dashboard = viz_dashboard.create_category_performance_dashboard()
        if recommendations_comparison:
            rec_quality_viz = viz_dashboard.visualize_recommendation_quality(sample_product_id, recommendations_comparison)
    except Exception as e:
        print(f"Visualization error (likely due to environment): {e}")

    # Business Intelligence Analysis
    print("\nBUSINESS INTELLIGENCE ANALYSIS...")
    summary_metrics = bi_engine.generate_executive_summary()

    print("\n" + "="*60)
    print("DETAILED ANALYSIS RESULTS")
    print("="*60)

    # Cross-selling opportunities
    print(f"\nCROSS-SELLING OPPORTUNITIES:")
    cross_sell_results = bi_engine.analyze_cross_selling_opportunities()
    print(cross_sell_results.head(10).to_string(index=False))

    # Pricing opportunities
    print(f"\nPRICING OPTIMIZATION OPPORTUNITIES:")
    pricing_results = bi_engine.identify_pricing_opportunities()
    print(pricing_results.head(10).to_string(index=False))

    # Product clustering insights
    print(f"\nPRODUCT CLUSTERING INSIGHTS:")
    clustering_results = bi_engine.generate_product_clustering_insights()
    print(clustering_results.head(8).to_string(index=False))

    # Brand positioning analysis
    print(f"\nBRAND POSITIONING ANALYSIS:")
    brand_results = bi_engine.analyze_brand_positioning()
    print(brand_results.head(8).to_string(index=False))

    # Advanced search & discovery
    print(f"\nADVANCED SEARCH & DISCOVERY INSIGHTS")
    print("="*50)

    # Semantic trend analysis
    print(f"\nSEMANTIC TREND ANALYSIS:")
    trend_results = search_discovery.semantic_trend_analysis()
    print(trend_results.head(8).to_string(index=False))


    # Bundle suggestions
    print(f"\nINTELLIGENT BUNDLE SUGGESTIONS:")
    bundle_results = search_discovery.intelligent_bundle_suggestions()
    print(bundle_results.head(6).to_string(index=False))

    # Personalized discovery demo
    print(f"\nPERSONALIZED DISCOVERY DEMO:")
    user_prefs = {
        'preferred_category': 'Jeans',
        'price_range': [25, 75]
    }
    personalized_results = search_discovery.personalized_discovery_engine(user_prefs)
    print(f"For user preferring {user_prefs['preferred_category']} in ${user_prefs['price_range'][0]}-{user_prefs['price_range'][1]} range:")
    print(personalized_results.head(8).to_string(index=False))

    # Final summary
    print("\n" + "="*80)
    print("VECTOR SEARCH ANALYSIS COMPLETE!")
    print("="*80)

    print(f"""
      ANALYSIS SUMMARY:
      ├── Products Analyzed: {summary_metrics['total_products']:,}
      ├── Cross-Sell Opportunities Found: {summary_metrics['cross_sell_opportunities']}
      ├── Pricing Optimization Cases: {summary_metrics['pricing_opportunities']}
      └── Brand Positioning Insights: {summary_metrics['brand_insights']}
    """)

    print("Analysis complete! All functions ready for interactive use.")

    return {
        'explorer': explorer,
        'rec_engine': rec_engine,
        'viz_dashboard': viz_dashboard,
        'bi_engine': bi_engine,
        'search_discovery': search_discovery,
        'summary_metrics': summary_metrics
    }

# %% [markdown]
# # INTERACTIVE FUNCTIONS FOR JUPYTER NOTEBOOKS

# %%
def quick_product_search(search_term, max_results=10):
    """
    Perform a quick product search using the SmartProductExplorer.

    Args:
        search_term (str): The term to search for.
        max_results (int): The maximum number of search results to return.

    Returns:
        pandas.DataFrame: A DataFrame containing the top matching products.
    """
    explorer = SmartProductExplorer(PROJECT_ID, DATASET_ID)
    return explorer.smart_search(search_term, max_results)

def get_recommendations(product_id, algorithm='hybrid', top_k=5):
    """
    Get recommendations for a specific product using the AdvancedRecommendationEngine.

    Args:
        product_id (int): The ID of the product for which to generate recommendations.
        algorithm (str): The recommendation algorithm to use ('semantic', 'hybrid', or 'business').
                         Defaults to 'hybrid'.
        top_k (int): The number of top recommendations to return.

    Returns:
        pandas.DataFrame: A DataFrame containing the recommendation results.
    """
    rec_engine = AdvancedRecommendationEngine(PROJECT_ID, DATASET_ID)

    if algorithm == 'semantic':
        return rec_engine.semantic_recommendations(product_id, top_k)
    elif algorithm == 'business':
        return rec_engine.business_smart_recommendations(product_id, top_k)
    else:  # hybrid
        return rec_engine.hybrid_recommendations(product_id, top_k)

def analyze_category_performance():
    """
    Analyze cross-selling opportunities using the BusinessIntelligenceEngine.

    Provides insights into potential product bundles based on semantic similarity
    between different categories.

    Returns:
        pandas.DataFrame: A DataFrame listing potential cross-selling pairs.
    """
    bi_engine = BusinessIntelligenceEngine(PROJECT_ID, DATASET_ID)
    return bi_engine.analyze_cross_selling_opportunities()

def find_bundle_opportunities(max_price=200):
    """
    Find intelligent bundle suggestions using the AdvancedSearchDiscovery.

    Identifies potential product bundles based on semantic similarity and
    a maximum bundle price.

    Args:
        max_price (int): The maximum combined price for suggested bundles.
                         Defaults to 200.

    Returns:
        pandas.DataFrame: A DataFrame listing intelligent bundle suggestions.
    """
    search_discovery = AdvancedSearchDiscovery(PROJECT_ID, DATASET_ID)
    return search_discovery.intelligent_bundle_suggestions(max_price)

def get_pricing_insights():
    """
    Get pricing optimization insights using the BusinessIntelligenceEngine.

    Identifies products that may be under- or over-priced based on market comparison.

    Returns:
        pandas.DataFrame: A DataFrame listing products with pricing recommendations.
    """
    bi_engine = BusinessIntelligenceEngine(PROJECT_ID, DATASET_ID)
    return bi_engine.identify_pricing_opportunities()

# %% [markdown]
# # MAIN EXECUTION

# %%
if __name__ == "__main__":
    # Run the complete analysis
    results = run_complete_analysis()

    # Store results in global variables for interactive use
    explorer = results['explorer']
    rec_engine = results['rec_engine']
    viz_dashboard = results['viz_dashboard']
    bi_engine = results['bi_engine']
    search_discovery = results['search_discovery']

    print("\nINTERACTIVE MODE READY!")
    print("Available functions:")
    print("quick_product_search('search_term')")
    print("get_recommendations(product_id, algorithm='hybrid')")
    print("analyze_category_performance()")
    print("find_bundle_opportunities(max_price=200)")
    print("get_pricing_insights()")
    print("\nAll class instances are available as global variables:")
    print("explorer, rec_engine, viz_dashboard, bi_engine, search_discovery")
# Out:
# STARTING COMPREHENSIVE VECTOR SEARCH ANALYSIS
# ================================================================================
#
# LOADING PRODUCTS WITH INSIGHTS...
# Query job b8fc9608-611c-4fb0-bb16-22c2864cb605 is DONE. 181.4 MB processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=bigquery-hackathon-471715&j=bq:US:b8fc9608-611c-4fb0-bb16-22c2864cb605&page=queryresults">Open Job</a>
# Loaded 29094 products with insights
#
# SMART SEARCH DEMO:
# Found 1917 products matching 'jacket'
#                                                  name           category  \
# 20              KASPER Metallic 2PC Jacket/Dress Suit              Suits
# 25  Voom by Joy Han Capelet Jacket - Pinstripe in ...  Blazers & Jackets
# 34  Port Authority Ladies Long Textured Hooded Sof...  Outerwear & Coats
# 57  Onyx-Arctic Shield-X-System Men's Arcticshield...  Outerwear & Coats
# 65  Allegra K Ladies Long Sleeve Knit Flower Neck ...  Blazers & Jackets
#
#                           brand          price_tier      brand_tier
# 20                       Kasper      Luxury ($100+)   Popular Brand
# 25                         Voom  Premium ($50-$100)  Boutique Brand
# 34               Port Authority  Premium ($50-$100)   Popular Brand
# 57  Onyx-Arctic Shield-X-System  Premium ($50-$100)  Boutique Brand
# 65                    Allegra K  Budget (Under $20)     Major Brand
#
# CATEGORY INSIGHTS:
#                                product_count  avg_price  min_price  max_price  \
# category
# Intimates                               2358      33.71       1.75      903.0
# Jeans                                   1997      97.89       9.99      389.0
# Fashion Hoodies & Sweatshirts           1865      53.92       8.88      903.0
# Tops & Tees                             1864      41.38       3.11      285.0
# Swim                                    1796      57.83       5.95      288.0
# Sleep & Lounge                          1770      49.23       2.99     399.95
# Shorts                                  1765      45.77       4.99      999.0
# Sweaters                                1737      75.32       5.99      588.0
# Accessories                             1557       42.6       0.02      299.0
# Active                                  1432      50.62       1.95      903.0
#
#                                unique_brands
# category
# Intimates                                356
# Jeans                                    222
# Fashion Hoodies & Sweatshirts            404
# Tops & Tees                              391
# Swim                                     272
# Sleep & Lounge                           285
# Shorts                                   390
# Sweaters                                 348
# Accessories                              419
# Active                                   271
#
# RECOMMENDATION ENGINE DEMO:
# Query job 60a95b6d-79b6-4ad8-91a8-d01e9939d05c is DONE. 2.7 MB processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=bigquery-hackathon-471715&j=bq:US:60a95b6d-79b6-4ad8-91a8-d01e9939d05c&page=queryresults">Open Job</a>
# COMPREHENSIVE RECOMMENDATIONS FOR:
#    Product: Wrangler Men's Western Traditional Boot Cut Slim Jean
#    Category: Jeans | Brand: Wrangler | Price: $49.99
# ====================================================================================================
# Query job 3ee1c8c3-92d5-4126-8040-cd5bdddb82ed is DONE. 181.4 MB processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=bigquery-hackathon-471715&j=bq:US:3ee1c8c3-92d5-4126-8040-cd5bdddb82ed&page=queryresults">Open Job</a>
# Query job 7359f4d5-88c6-4daa-8cdf-539c591f7b15 is DONE. 181.4 MB processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=bigquery-hackathon-471715&j=bq:US:7359f4d5-88c6-4daa-8cdf-539c591f7b15&page=queryresults">Open Job</a>
# Query job 23b43df1-21f1-4016-9f08-bf207f30e082 is DONE. 182.1 MB processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=bigquery-hackathon-471715&j=bq:US:23b43df1-21f1-4016-9f08-bf207f30e082&page=queryresults">Open Job</a>
# Semantic RECOMMENDATIONS:
# --------------------------------------------------
#   1. Wrangler Men's Western Slim Boot Cut Jean...
#      Category: Jeans | Brand: Wrangler | Price: $49.99
#      Score: 0.990 | Semantic Similarity
#   2. Wrangler Men's Western Boot Cut Slim Jean...
#      Category: Jeans | Brand: Wrangler | Price: $35.95
#      Score: 0.990 | Semantic Similarity
#   3. Wrangler Men's Cowboy Cut Western Slim Fit Jean...
#      Category: Jeans | Brand: Wrangler | Price: $40.72
#      Score: 0.974 | Semantic Similarity
#
# Hybrid RECOMMENDATIONS:
# --------------------------------------------------
#   1. Wrangler Men's Cowboy Cut Original Fit Jean...
#      Category: Jeans | Brand: Wrangler | Price: $49.99
#   2. Wrangler Men's Western Slim Boot Cut Jean...
#      Category: Jeans | Brand: Wrangler | Price: $49.99
#   3. Wrangler Men's Cowboy Cut Slim Fit Jean...
#      Category: Jeans | Brand: Wrangler | Price: $49.99
#
# Business RECOMMENDATIONS:
# --------------------------------------------------
#   1. Wrangler Men's Western Boot Cut Slim Jean...
#      Category: Jeans | Brand: Wrangler | Price: $35.95
#      Score: 0.993 | Good Profit Recommendation
#   2. Wrangler Men's Western Slim Boot Cut Jean...
#      Category: Jeans | Brand: Wrangler | Price: $49.99
#      Score: 0.993 | Good Profit Recommendation
#   3. Wrangler Men's Cowboy Cut Western Slim Fit Jean...
#      Category: Jeans | Brand: Wrangler | Price: $40.72
#      Score: 0.982 | Good Profit Recommendation
#
# CREATING INTERACTIVE VISUALIZATIONS...
# Query job a6e3b587-de3b-4b09-922b-d40177d0a473 is DONE. 2.1 MB processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=bigquery-hackathon-471715&j=bq:US:a6e3b587-de3b-4b09-922b-d40177d0a473&page=queryresults">Open Job</a>
# Query job 1ffd1d69-4ed3-417e-8998-873cc10dfc1a is DONE. 180.5 MB processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=bigquery-hackathon-471715&j=bq:US:1ffd1d69-4ed3-417e-8998-873cc10dfc1a&page=queryresults">Open Job</a>
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="90817e69-3ea3-4866-a15d-76a6bbec93a3" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("90817e69-3ea3-4866-a15d-76a6bbec93a3")) {                    Plotly.newPlot(                        "90817e69-3ea3-4866-a15d-76a6bbec93a3",                        [{"coloraxis":"coloraxis","name":"0","x":["Allegra K Mens Styli...","American Apparel Nat...","Nursing bra with und...","RVCA Men's Regulars ...","Socksmith Sock Monke...","Stacy Adams 6-027 Sn...","Women's Cotton Croch...","allen allen Women's ..."],"y":["Allegra K Mens Styli...","American Apparel Nat...","Nursing bra with und...","RVCA Men's Regulars ...","Socksmith Sock Monke...","Stacy Adams 6-027 Sn...","Women's Cotton Croch...","allen allen Women's ..."],"z":[[1.0,0.46,0.505,0.528,0.504,0.565,0.533,0.591],[0.46,1.0,0.536,0.572,0.52,0.519,0.597,0.602],[0.505,0.536,1.0,0.441,0.543,0.471,0.583,0.567],[0.528,0.572,0.441,1.0,0.467,0.519,0.469,0.626],[0.504,0.52,0.543,0.467,1.0,0.553,0.574,0.581],[0.565,0.519,0.471,0.519,0.553,1.0,0.495,0.491],[0.533,0.597,0.583,0.469,0.574,0.495,1.0,0.588],[0.591,0.602,0.567,0.626,0.581,0.491,0.588,1.0]],"type":"heatmap","xaxis":"x","yaxis":"y","hovertemplate":"x: %{x}\u003cbr\u003ey: %{y}\u003cbr\u003eSimilarity Score: %{z}\u003cextra\u003e\u003c\u002fextra\u003e"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca ...
# Query job 96594e6b-41b8-43ed-8cd7-7171d4fc8849 is DONE. 1.9 MB processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=bigquery-hackathon-471715&j=bq:US:96594e6b-41b8-43ed-8cd7-7171d4fc8849&page=queryresults">Open Job</a>
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="c7846937-60fe-4a10-a1f6-ae432e80e59e" class="plotly-graph-div" style="height:800px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c7846937-60fe-4a10-a1f6-ae432e80e59e")) {                    Plotly.newPlot(                        "c7846937-60fe-4a10-a1f6-ae432e80e59e",                        [{"marker":{"color":"lightblue"},"name":"Product Count","x":["Jumpsuits & Rompers","Intimates","Swim","Maternity","Jeans","Socks & Hosiery","Sweaters","Suits & Sport Coats","Outerwear & Coats","Dresses"],"y":[162,2358,1796,898,1997,665,1737,739,1416,955],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"lightcoral"},"name":"Avg Price","x":["Jumpsuits & Rompers","Intimates","Swim","Maternity","Jeans","Socks & Hosiery","Sweaters","Suits & Sport Coats","Outerwear & Coats","Dresses"],"y":[45.42216063134461,33.70507214178563,57.83243882470244,50.79920925966616,97.89139223027124,16.761097715134053,75.31898100319857,126.55561555803072,146.20433603976397,84.20327769574068],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"green","size":10},"mode":"markers+text","name":"Brand Diversity","text":["Jumpsuits & Rompers","Intimates","Swim","Maternity","Jeans","Socks & Hosiery","Sweaters","Suits & Sport Coats","Outerwear & Coats","Dresses"],"textposition":"top center","x":[162,2358,1796,898,1997,665,1737,739,1416,955],"y":[56,356,272,158,222,171,348,145,285,180],"type":"scatter","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"gold"},"name":"Profit Margin %","x":["Jumpsuits & Rompers","Intimates","Swim","Maternity","Jeans","Socks & Hosiery","Sweaters","Suits & Sport Coats","Outerwear & Coats","Dresses"],"y":[47.11604944795348,46.94359633404389,48.867371771264246,55.84565687748066,46.41347028390033,59.8660151879969,52.14271735821924,59.93247646454051,55.47584741068701,54.8723560967239],"type":"bar","xaxis":"x4","yaxis":"y4"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.33333333333 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="454efa28-9224-40b0-b9a6-8e98cd586ec2" class="plotly-graph-div" style="height:500px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("454efa28-9224-40b0-b9a6-8e98cd586ec2")) {                    Plotly.newPlot(                        "454efa28-9224-40b0-b9a6-8e98cd586ec2",                        [{"alignmentgroup":"True","customdata":[["Jeans",49.9900016784668,""],["Jeans",35.95000076293945,""],["Jeans",40.720001220703125,""]],"hovertemplate":"Algorithm=Semantic\u003cbr\u003eProduct=%{x}\u003cbr\u003eScore=%{y}\u003cbr\u003eCategory=%{customdata[0]}\u003cbr\u003ePrice=%{customdata[1]}\u003cbr\u003eExplanation=%{customdata[2]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Semantic","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Semantic","offsetgroup":"Semantic","orientation":"v","showlegend":true,"textposition":"auto","x":["Wrangler Men's Western Slim Bo...","Wrangler Men's Western Boot Cu...","Wrangler Men's Cowboy Cut West..."],"xaxis":"x","y":[0.9897,0.9901,0.9741],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["Jeans",49.9900016784668,"Perfect Match (Same Brand & Category)"],["Jeans",49.9900016784668,"Perfect Match (Same Brand & Category)"],["Jeans",49.9900016784668,"Perfect Match (Same Brand & Category)"]],"hovertemplate":"Algorithm=Hybrid\u003cbr\u003eProduct=%{x}\u003cbr\u003eScore=%{y}\u003cbr\u003eCategory=%{customdata[0]}\u003cbr\u003ePrice=%{customdata[1]}\u003cbr\u003eExplanation=%{customdata[2]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Hybrid","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Hybrid","offsetgroup":"Hybrid","orientation":"v","showlegend":true,"textposition":"auto","x":["Wrangler Men's Cowboy Cut Orig...","Wrangler Men's Western Slim Bo...","Wrangler Men's Cowboy Cut Slim..."],"xaxis":"x","y":[0.9674,0.9938,0.9805],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["Jeans",35.95000076293945,"Good Profit Recommendation"],["Jeans",49.9900016784668,"Good Profit Recommendation"],["Jeans",40.720001220703125,"Good Profit Recommendation"]],"hovertemplate":"Algorithm=Business\u003cbr\u003eProduct=%{x}\u003cbr\u003eScore=%{y}\u003cbr\u003eCategory=%{customdata[0]}\u003cbr\u003ePrice=%{customdata[1]}\u003cbr\u003eExplanation=%{customdata[2]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Business","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Business","offsetgroup":"Business","orientation":"v","showlegend":true,"textposition":"auto","x":["Wrangler Men's Western Boot Cu...","Wrangler Men's Western Slim Bo...","Wrangler Men's Cowboy Cut West..."],"xaxis":"x","y":[0.9931,0.9928,0.9818],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3 ...
# BUSINESS INTELLIGENCE ANALYSIS...
# EXECUTIVE BUSINESS INTELLIGENCE SUMMARY
# ============================================================
# Query job 0c8f5879-0860-45c1-89dd-6b6e64bd5fb7 is DONE. 0 Bytes processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=bigquery-hackathon-471715&j=bq:US:0c8f5879-0860-45c1-89dd-6b6e64bd5fb7&page=queryresults">Open Job</a>
# Query job d2b3b4f5-3880-48ae-9fe6-eafe5accacc1 is DONE. 360.9 kB processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=bigquery-hackathon-471715&j=bq:US:d2b3b4f5-3880-48ae-9fe6-eafe5accacc1&page=queryresults">Open Job</a>
# Query job afd912bf-1f17-4bca-8cfa-332b47655aca is DONE. 349.8 kB processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=bigquery-hackathon-471715&j=bq:US:afd912bf-1f17-4bca-8cfa-332b47655aca&page=queryresults">Open Job</a>
# PORTFOLIO OVERVIEW:
# Total Products: 29,094
# Categories: 26
# Brands: 2756
# Query job 5edd63ae-bf31-466d-bd1f-d87ea325e39a is DONE. 179.3 MB processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=bigquery-hackathon-471715&j=bq:US:5edd63ae-bf31-466d-bd1f-d87ea325e39a&page=queryresults">Open Job</a>
# TOP CROSS-SELLING OPPORTUNITIES:
#    1. Leggings ↔ Pants & Capris
#       Semantic Affinity: 0.613 | Bundle Value: $81.86
#    2. Leggings ↔ Socks & Hosiery
#       Semantic Affinity: 0.603 | Bundle Value: $43.91
#    3. Suits ↔ Blazers & Jackets
#       Semantic Affinity: 0.612 | Bundle Value: $208.76
# Query job 0f373058-3365-4b1f-b02b-2e34d583b12e is DONE. 181.4 MB processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=bigquery-hackathon-471715&j=bq:US:0f373058-3365-4b1f-b02b-2e34d583b12e&page=queryresults">Open Job</a>
# PRICING INSIGHTS:
#  Under-priced Products: 3
#  Over-priced Products: 27
#    • Avg. Price Increase Opportunity: 42.1%
# Query job 297993f9-7153-4b9a-8eb2-6605ecb472bb is DONE. 179.3 MB processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=bigquery-hackathon-471715&j=bq:US:297993f9-7153-4b9a-8eb2-6605ecb472bb&page=queryresults">Open Job</a>
# BRAND POSITIONING:
#  Premium Brands: 1
#  Value Brands: 9
#  Most Competitive Space: Lysse Leggings (Score: 0.579)
#
# ============================================================
# DETAILED ANALYSIS RESULTS
# ============================================================
#
# CROSS-SELLING OPPORTUNITIES:
# Query job 94418390-c149-4d74-ad0a-2e194a93eb0b is DONE. 179.3 MB processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=bigquery-hackathon-471715&j=bq:US:94418390-c149-4d74-ad0a-2e194a93eb0b&page=queryresults">Open Job</a>
#              primary_category cross_sell_category  similar_product_pairs  semantic_affinity  avg_primary_price  avg_cross_sell_price  potential_bundle_value   opportunity_rating
#                      Leggings      Pants & Capris                 345732              0.613              27.15                 54.71                   81.86 Excellent Cross-Sell
#                      Leggings     Socks & Hosiery                 375060              0.603              27.15                 16.76                   43.91 Excellent Cross-Sell
#                         Suits   Blazers & Jackets                 105468              0.612             116.16                  92.6                  208.76 Excellent Cross-Sell
#                         Pants               Jeans                2078877               0.61              59.81                 97.89                  157.71 Excellent Cross-Sell
#                         Pants      Pants & Capris                 638133              0.618              59.81                 54.71                  114.52 Excellent Cross-Sell
#                         Socks     Socks & Hosiery                 600495              0.631              20.42                 16.76                   37.18 Excellent Cross-Sell
#             Blazers & Jackets               Suits                 105468              0.612               92.6                116.16                  208.76 Excellent Cross-Sell
# Fashion Hoodies & Sweatshirts            Sweaters                3239505              0.601              53.92                 75.32                  129.24 Excellent Cross-Sell
#           Suits & Sport Coats               Suits                 138932              0.603             126.56                116.16                  242.72 Excellent Cross-Sell
#                         Jeans               Pants                2078877               0.61              97.89                 59.81                  157.71 Excellent Cross-Sell
#
# PRICING OPTIMIZATION OPPORTUNITIES:
# Query job 518c08f8-b387-4f68-9eb0-9b4a1fffce15 is DONE. 181.4 MB processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=bigquery-hackathon-471715&j=bq:US:518c08f8-b387-4f68-9eb0-9b4a1fffce15&page=queryresults">Open Job</a>
#    id                                                   name  category             brand  current_price  market_avg_price  similar_products_count  price_gap  price_gap_percent              pricing_recommendation  confidence_level
# 21260                   True Religion Men's Bobby Super Jean     Jeans     True Religion          383.0            231.55                     171    -151.45              -39.5         Over-priced (Decrease Risk)   High Confidence
# 13164                 Karla Colletto Outlines One Piece Tank      Swim    Karla Colletto          285.0            170.76                      82    -114.24              -40.1         Over-priced (Decrease Risk)   High Confidence
# 21574         Evisu European edition Vintage cut denim jeans     Jeans             Evisu         349.17            212.36                     284    -136.81              -39.2         Over-priced (Decrease Risk)   High Confidence
#   935           Turtle Neck Dickey Inner Sweater Many Colors  Sweaters NYGiftStop Winter           5.99              8.61                       7       2.62               43.7 Under-priced (Increase Opportunity) Medium Confidence
# 13022                    Karla Colletto Gold Trim Tank Dress      Swim    Karla Colletto          288.0             172.5                      77     -115.5              -40.1         Over-priced (Decrease Risk)   High Confidence
# 21142 True Religion Men's Ricky Super T Straight Stitch Jean     Jeans     True Religion          352.0            213.54                     275    -138.46              -39.3         Over-priced (Decrease Risk)   High Confidence
# 11152                 Ardyss Body Magic Body Shaper Style 22 Intimates            Ardyss          195.0            119.77                      54     -75.23              -38.6         Over-priced (Decrease Risk)   High Confidence
# 21520          Diesel Men's Shioner Skinny Straight Leg Jean     Jeans            Diesel          328.0            200.83                     388    -127.17              -38.8         Over-priced (Decrease Risk)   High Confidence
# 21555        True Religion Men's Ricky Super T Straight Jean     Jeans     True Religion          389.0            233.12                     164    -155.88              -40.1         Over-priced (Decrease Risk)   High Confidence
# 21227           Diesel Men's Braddom Regular Carrot-Leg Jean     Jeans            Diesel          350.0            212.36                     284    -137.64              -39.3         Over-priced (Decrease Risk)   High Confidence
#
# PRODUCT CLUSTERING INSIGHTS:
# Query job 8073b83a-629c-4e92-8d05-0d6316d27744 is DONE. 181.4 MB processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=bigquery-hackathon-471715&j=bq:US:8073b83a-629c-4e92-8d05-0d6316d27744&page=queryresults">Open Job</a>
#  product_id                                                         product_name product_category           brand  retail_price                                                 cross_category_match match_category  cross_category_similarity           market_positioning
#       15479                                    Levi Women's Plus Size Flare Jean             Plus          Levi's     42.990002                                    Levi Women's Plus Size Flare Jean          Jeans                      0.997 Strong Cross-Category Appeal
#        4329 Levi's Women's Plus-Size 580 Defined Waist Boot Cut Regular Fit Jean            Jeans          Levi's     47.990002 Levi's Women's Plus-Size 580 Defined Waist Boot Cut Regular Fit Jean           Plus                      0.997 Strong Cross-Category Appeal
#       12753    Woman Within Plus Size Cover-up for swimsuit hooded in terrycloth             Swim    Woman Within     44.990002    Woman Within Plus Size Cover-up for swimsuit hooded in terrycloth           Plus                      0.997 Strong Cross-Category Appeal
#       12760                 Resorts Plus Plus Size Cover-up for swimsuit Swim365             Swim    Resorts Plus     39.990002                 Resorts Plus Plus Size Cover-up for swimsuit Swim365           Plus                      0.998 Strong Cross-Category Appeal
#       15686    Woman Within Plus Size Cover-up for swimsuit hooded in terrycloth             Plus    Woman Within     44.990002    Woman Within Plus Size Cover-up for swimsuit hooded in terrycloth           Swim                      0.997 Strong Cross-Category Appeal
#       15719                Plus Size Zipper Front Belt Accented Mini Dress Black             Plus eVogues Apparel     39.990002                Plus Size Zipper Front Belt Accented Mini Dress Black        Dresses                      0.997 Strong Cross-Category Appeal
#       12765                       Swim 365 Plus Size Swimsuit Surplice swimdress             Swim        Swim 365     89.989998                       Swim 365 Plus Size Swimsuit Surplice swimdress           Plus                      0.999 Strong Cross-Category Appeal
#       15542    Dreams & CoÂ® Plus Size Sleepwear gown in cotton knit Dreams & Co             Plus          DREAMS         19.99    Dreams & CoÂ® Plus Size Sleepwear gown in cotton knit Dreams & Co Sleep & Lounge                      0.997 Strong Cross-Category Appeal
#
# BRAND POSITIONING ANALYSIS:
# Query job 74fd446a-75dd-4855-8e26-8b7fb7e0e7c9 is DONE. 179.3 MB processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=bigquery-hackathon-471715&j=bq:US:74fd446a-75dd-4855-8e26-8b7fb7e0e7c9&page=queryresults">Open Job</a>
#          brand  competing_brands  market_similarity_score  avg_price_point  avg_competing_products competitive_landscape price_positioning
# Lysse Leggings              1259                    0.579            66.01                    38.4  Moderate Competition  Mid-Market Brand
# Alice & Olivia               858                    0.579            152.0                    25.8  Moderate Competition     Premium Brand
#       under.me               854                     0.58             24.0                    25.5  Moderate Competition       Value Brand
#       Lingerie               762                    0.587            12.99                    23.4  Moderate Competition       Value Brand
# Snug Camisoles              1226                    0.579            37.99                    36.2  Moderate Competition  Mid-Market Brand
#    Cotton Glam               925                     0.59             46.0                    26.0  Moderate Competition  Mid-Market Brand
#           Swan               887                     0.58             16.0                    25.7  Moderate Competition       Value Brand
#    NEARLY NUDE               877                    0.584             68.0                    25.5  Moderate Competition  Mid-Market Brand
#
# ADVANCED SEARCH & DISCOVERY INSIGHTS
# ==================================================
#
# SEMANTIC TREND ANALYSIS:
# Query job 1d0ded17-3ec6-47e5-9fbd-5768c0f25919 is DONE. 179.9 MB processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=bigquery-hackathon-471715&j=bq:US:1d0ded17-3ec6-47e5-9fbd-5768c0f25919&page=queryresults">Open Job</a>
#            category          brand  product_count  avg_price  semantic_coherence brand_focus_strategy
#               Suits         Kasper             30     153.88               0.725 Highly Focused Brand
# Jumpsuits & Rompers   LOTUSTRADERS              8      49.62               0.728 Highly Focused Brand
# Jumpsuits & Rompers  BCBGeneration              3      68.13               0.728 Highly Focused Brand
#               Suits Danny & Nicole              4      61.98               0.725 Highly Focused Brand
# Jumpsuits & Rompers          MANGO              3      38.32               0.728 Highly Focused Brand
#               Socks          Hanes             31      13.41                0.71 Highly Focused Brand
#               Suits        Roamans              3      94.99               0.725 Highly Focused Brand
#               Socks       Gold Toe             39      24.69                0.71 Highly Focused Brand
#
# INTELLIGENT BUNDLE SUGGESTIONS:
# Query job 595823e0-33e4-4c6c-9667-4a954bc17c5c is DONE. 181.1 MB processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=bigquery-hackathon-471715&j=bq:US:595823e0-33e4-4c6c-9667-4a954bc17c5c&page=queryresults">Open Job</a>
#                                                                      product1_name product1_category  product1_price                                                                      product2_name product2_category  product2_price  bundle_price  compatibility_score bundle_quality  suggested_discount  discounted_price
# Woman Within Plus Size Top in tunic length the Perfect cotton V-neck with shirring       Tops & Tees           13.99 Woman Within Plus Size Top in tunic length the Perfect cotton V-neck with shirring              Plus           13.99         27.98                0.997 Perfect Bundle                 2.8             25.18
#              Woman Within Plus Size Top in soft knit the Perfect cotton V-neck tee       Tops & Tees           11.99              Woman Within Plus Size Top in soft knit the Perfect cotton V-neck tee              Plus           11.99         23.98                0.997 Perfect Bundle                 2.4             21.58
#                           Woman Within Plus Size Top 2-in-1 t-shirt with lace trim       Tops & Tees           29.99                           Woman Within Plus Size Top 2-in-1 t-shirt with lace trim              Plus           29.99         59.98                0.997 Perfect Bundle                 6.0             53.98
#                                   Inches Off Plus Size Swimsuit with colorblocking              Swim           49.99                                   Inches Off Plus Size Swimsuit with colorblocking              Plus           49.99         99.98                0.998 Perfect Bundle                10.0             89.98
#                                       Star Vixen Women's Plus-Size Full Wrap Dress           Dresses            50.0                                       Star Vixen Women's Plus-Size Full Wrap Dress              Plus            50.0         100.0                0.996 Perfect Bundle                10.0              90.0
#                               Resorts Plus Plus Size Cover-up for swimsuit Swim365              Swim           39.99                               Resorts Plus Plus Size Cover-up for swimsuit Swim365              Plus           39.99         79.98                0.998 Perfect Bundle                 8.0             71.98
#
# PERSONALIZED DISCOVERY DEMO:
# Query job 99ef6188-8b71-423f-a3fa-ce97a5a704b5 is DONE. 181.2 MB processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=bigquery-hackathon-471715&j=bq:US:99ef6188-8b71-423f-a3fa-ce97a5a704b5&page=queryresults">Open Job</a>
# For user preferring Jeans in $25-75 range:
#                                                        name       category      brand  price  recommendation_score recommendation_type
#      Levi's Women's 512 Plus-Size Straight Leg Stretch Jean           Plus     Levi's  47.99                 0.945      Discovery Pick
#                        Levi Women's Plus Size Stretch Denim           Plus     Levi's  42.99                 0.953      Discovery Pick
# Levi's Women's Petite 515 Styled Mid Rise Boot Cut Corduroy Pants & Capris     Levi's  44.99                 0.927      Discovery Pick
#         Levi's Men's 508 Regular Tapered Brushed Twill Pant          Pants     Levi's  47.99                 0.929      Discovery Pick
#              Lee Jeans Women's Relaxed Fit Plain Front Pant Pants & Capris        Lee   52.0                 0.943      Discovery Pick
#         Levi's Women's Mid Rise Styled Skinny Slim Fit Pant Pants & Capris     Levi's  43.99                 0.957      Discovery Pick
#                        Quiksilver Men's Sequel Stretch Jean          Pants Quiksilver   69.5                 0.933      Discovery Pick
#                           Levi Women's Plus Size Flare Jean           Plus     Levi's  42.99                 0.941      Discovery Pick
#
# ================================================================================
# VECTOR SEARCH ANALYSIS COMPLETE!
# ================================================================================
#
#       ANALYSIS SUMMARY:
#       ├── Products Analyzed: 29,094
#       ├── Cross-Sell Opportunities Found: 20
#       ├── Pricing Optimization Cases: 30
#       └── Brand Positioning Insights: 20
#
# Analysis complete! All functions ready for interactive use.
#
# INTERACTIVE MODE READY!
# Available functions:
# quick_product_search('search_term')
# get_recommendations(product_id, algorithm='hybrid')
# analyze_category_performance()
# find_bundle_opportunities(max_price=200)
# get_pricing_insights()
#
# All class instances are available as global variables:
# explorer, rec_engine, viz_dashboard, bi_engine, search_discovery
